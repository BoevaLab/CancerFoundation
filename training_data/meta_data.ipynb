# %%
import pandas as pd

# %%
anatomical_mapping = {
    # Head and neck region
    'Head and neck': 'head-and-neck',
    'Tongue': 'head-and-neck',
    'Tongue/Tonsil': 'head-and-neck',
    'Laryngeal tissue': 'head-and-neck',
    'Hypopharynx': 'head-and-neck',
    'Epiglottis': 'head-and-neck',
    
    # Brain and neural tissue
    'Brain': 'brain',
    'Cerebellum': 'brain',
    'Spinal cord': 'brain',
    'Nerve': 'brain',
    'Retina': 'brain',
    
    # Lung
    'Lung': 'lung',
    
    # Liver and biliary system
    'Liver': 'liverbiliary',
    'Gall bladder': 'liverbiliary',
    
    # Kidney
    'Kidney': 'kidney',
    
    # Prostate
    'Prostate': 'prostate',
    
    # Bone and soft tissue
    'Bone': 'sarcoma',
    'Hip': 'sarcoma',
    
    # Brain and neural tissue
    'Brain': 'brain',
    
    # Breast
    'Breast': 'breast',
    
    # Pancreas
    'Pancreas': 'pancreas',
    
    # Neuroendocrine tissues
    'Thyroid': 'neuroendocrine',
    'Adrenal gland': 'neuroendocrine',
    
    # Colorectal system
    'Colon': 'colorectal',
    'Colorectum': 'colorectal',
    'Sigmoid': 'colorectal',
    'Rectum': 'colorectal',
    
    # Ovarian
    'Ovary': 'ovarian',
    
    # Skin
    'Skin': 'skin',
    'Glabrous acral skin': 'skin',
    
    # Blood and bone marrow
    'Blood': 'hematologic',
    'Bone marrow': 'hematologic',
    
    # Items mapped to othermodels (no clear corresponding category)
    'Small intestine': 'othermodels',
    'Left arm': 'othermodels',
    'Endometrium': 'othermodels',
    'Bladder': 'othermodels',
    'Esophagus': 'othermodels',
    'Testis': 'othermodels',
    'Uterus': 'othermodels',
    'Mesothelium': 'othermodels',
    'Appendix': 'othermodels',
    'Cervix': 'othermodels'
}

technology_mapping = {
    '10X Genomics': '10x',  # Standard naming variation
    'Drop-seq': 'Drop-seq',  # Exact match
    'Smart-seq2': 'SmartSeq2',  # Minor formatting difference
    'Seq-Well': 'Seq-Well',  # Exact match
    'Microwell': 'Microwell-seq',  # Most similar match
    
}

cancer_mapping = {
    # Direct matches
    'Merkel Cell Carcinoma': 'Merkel cell carcinoma',
    'Lung Adenocarcinoma': 'Lung adenocarcinoma',
    'Non-small Cell Lung Cancer': 'NSCLC',
    'Neuroblastoma': 'Neuroblastoma',
    'Breast Cancer': 'Breast cancer',
    'Colorectal Cancer': 'Colorectal cancer',
    'Triple Negative Breast Cancer': 'TNBC',
    'Acute Myeloid Leukemia': 'AML',
    'Melanoma': 'Melanoma',
    'Cutaneous Melanoma': 'Primary melanoma',
    'Prostate Cancer': 'Prostate cancer',
    'Clear Cell Renal Cell Carcinoma': 'RCC',
    'Hepatocellular Cancer': 'HCC',
    'Wilms Tumor': 'Wilms tumor',
    'Glioblastoma': 'GBM',
    'Medulloblastoma': 'Medulloblastoma',
    'Pediatric Ependymoma': 'Pediatric ependymoma',
    'Head and Neck Squamous Cell Carcinoma': 'HNSCC',
    'Esophageal Squamous Cell Carcinoma': 'ESCC',
    'Pancreatic Ductal Adenocarcinoma': 'PDAC',
    'High-grade Serous Ovarian Carcinoma': 'HGSOC',
    'Ovarian Carcinoma': 'Ovarian cancer',
    'Cutaneous Squamous Cell Carcinoma': 'Skin SCC',
    'Basal Cell Carcinoma': 'BCC',
    'Neuroendocrine Tumor': 'Small intestinal neuroendocrine tumor'
}

# %%
ccca = pd.read_csv("3ca.csv", index_col=0)
scem = pd.read_csv("scem.csv")
scem = scem[scem["year"].notna()]

# %%
scem = scem.rename(columns={"url": "Article", "n_samples": "N_samples"})
ccca = ccca.rename(columns={"N_sampels": "N_samples"})

# %%
scem["Source"] = "CancerSCEM"
ccca["Source"] = "3ca"

# %%
scem["Tissue"] = scem["primary_site"].map(anatomical_mapping.get)

# %%
scem["Technology"] = scem["protocol"].map(lambda x: technology_mapping.get(x, x))

# %%
ccca["author_last_name"] = ccca["Title"].str.split(" et al. ").str[0]
ccca["year"] = ccca["Title"].str.split(" et al. ").str[1]

# %%
scem["Disease"] = scem["cancer_type"].map(lambda x: cancer_mapping.get(x, x))

# %%
ccca["Project ID"] = [f"CCCA-{i+1}" for i in range(ccca.shape[0])]

# %%
ccca.index = ccca["author_last_name"] + "_" + ccca["year"].astype(str) + "_" + ccca["Tissue"]
scem.index = scem["author_last_name"] + "_" + scem["year"].astype(int).astype(str) + "_" + scem["Tissue"]

# %%
combined = pd.concat([ccca, scem])[['Tissue', 'Article','Disease',
       'Technology', 'N_samples', 'Source', 'author_last_name',
       'year', 'Project ID']]

combined["year"] = combined["year"].astype(int)
combined["N_samples"] = combined["N_samples"].astype(int)
combined.to_csv("studies.csv")

# %%
combined[["N_samples"]].value_counts().sort_index(ascending=True)
# Out:
# N_samples
# 1             1
# 2            21
# 3            19
# 4            20
# 5             9
# 6            15
# 7            10
# 8            13
# 9             1
# 10           12
# 11            6
# 12            6
# 13            7
# 14            8
# 15           10
# 16            6
# 17            3
# 18            9
# 19            1
# 20            1
# 21            1
# 22            2
# 23            1
# 24            3
# 25            2
# 26            3
# 29            3
# 30            1
# 31            2
# 32            3
# 33            2
# 36            2
# 37            2
# 38            1
# 40            3
# 41            1
# 42            3
# 43            1
# 45            1
# 48            1
# 50            1
# 53            1
# 56            2
# 58            2
# 60            1
# 61            1
# 66            1
# 74            1
# 95            1
# 100           1
# 121           1
# 198           1
# Name: count, dtype: int64

# %%
scem
# Out:
#                        Unnamed: 0 Project ID                authors  \
# Paulson_2018_skin               0    MCC-001   K.G. Paulson et al.,
# Paulson_2018_skin               1    MCC-002   K.G. Paulson et al.,
# Laughney_2020_lung              2   LUAD-003  A.M. Laughney et al.,
# Lambrechts_2018_lung            3   LUAD-004  D. Lambrechts et al.,
# Lambrechts_2018_lung            4   LUSC-005  D. Lambrechts et al.,
# ...                           ...        ...                    ...
# Li_2023_head-and-neck         104   HSCC-130           C. Li et al.
# Oh_2023_pancreas              105   PDAC-132          K. Oh et al.,
# Yang_2023_colorectal          106    CRC-133        M. Yang et al.,
# Song_2023_breast              107   BRCA-134        Q. Song et al.,
# Xu_2022_breast                108   BRCA-135          K. Xu et al.,
#
#                       author_last_name  \
# Paulson_2018_skin              Paulson
# Paulson_2018_skin              Paulson
# Laughney_2020_lung            Laughney
# Lambrechts_2018_lung        Lambrechts
# Lambrechts_2018_lung        Lambrechts
# ...                                ...
# Li_2023_head-and-neck               Li
# Oh_2023_pancreas                    Oh
# Yang_2023_colorectal              Yang
# Song_2023_breast                  Song
# Xu_2022_breast                      Xu
#
#                                                          Article  \
# Paulson_2018_skin      https://pubmed.ncbi.nlm.nih.gov/30250229/
# Paulson_2018_skin      https://pubmed.ncbi.nlm.nih.gov/30250229/
# Laughney_2020_lung     https://pubmed.ncbi.nlm.nih.gov/32042191/
# Lambrechts_2018_lung   https://pubmed.ncbi.nlm.nih.gov/29988129/
# Lambrechts_2018_lung   https://pubmed.ncbi.nlm.nih.gov/29988129/
# ...                                                          ...
# Li_2023_head-and-neck  https://pubmed.ncbi.nlm.nih.gov/37503341/
# Oh_2023_pancreas       https://pubmed.ncbi.nlm.nih.gov/37633924/
# Yang_2023_colorectal   https://pubmed.ncbi.nlm.nih.gov/37576892/
# Song_2023_breast       https://pubmed.ncbi.nlm.nih.gov/37479733/
# Xu_2022_breast         https://pubmed.ncbi.nlm.nih.gov/36148946/
#
#                                                                  details  \
# Paulson_2018_skin      Acquired cancer resistance to combination immu...
# Paulson_2018_skin      Acquired cancer resistance to combination immu...
# Laughney_2020_lung     Regenerative lineages and immune-mediated prun...
# Lambrechts_2018_lung   Phenotype molding of stromal cells in the lung...
# Lambrechts_2018_lung   Phenotype molding of stromal cells in the lung...
# ...                                                                  ...
# Li_2023_head-and-neck  Single-cell RNA sequencing reveals tumor immun...
# Oh_2023_pancreas       Coordinated single-cell tumor microenvironment...
# Yang_2023_colorectal   Single-cell analysis reveals cellular reprogra...
# Song_2023_breast       Single-cell sequencing reveals the landscape o...
# Xu_2022_breast         Microenvironment components and spatially reso...
#
#                          year  \
# Paulson_2018_skin      2018.0
# Paulson_2018_skin      2018.0
# Laughney_2020_lung     2020.0
# Lambrechts_2018_lung   2018.0
# Lambrechts_2018_lung   2018.0
# ...                       ...
# Li_2023_head-and-neck  2023.0
# Oh_2023_pancreas       2023.0
# Yang_2023_colorectal   2023.0
# Song_2023_breast       2023.0
# Xu_2022_breast         2022.0
#
#                                                            full_citation  \
# Paulson_2018_skin      K.G. Paulson et al.,Acquired cancer resistance...
# Paulson_2018_skin      K.G. Paulson et al.,Acquired cancer resistance...
# Laughney_2020_lung     A.M. Laughney et al.,Regenerative lineages and...
# Lambrechts_2018_lung   D. Lambrechts et al.,Phenotype molding of stro...
# Lambrechts_2018_lung   D. Lambrechts et al.,Phenotype molding of stro...
# ...                                                                  ...
# Li_2023_head-and-neck                                                NaN
# Oh_2023_pancreas       K. Oh et al.,Coordinated single-cell tumor mic...
# Yang_2023_colorectal   M. Yang et al.,Single-cell analysis reveals ce...
# Song_2023_breast       Q. Song et al.,Single-cell sequencing reveals ...
# Xu_2022_breast         K. Xu et al.,Microenvironment components and s...
#
#                                                  cancer_type cancer_type_abbr  \
# Paulson_2018_skin                      Merkel Cell Carcinoma              MCC
# Paulson_2018_skin                      Merkel Cell Carcinoma              MCC
# Laughney_2020_lung                       Lung Adenocarcinoma             LUAD
# Lambrechts_2018_lung                     Lung Adenocarcinoma             LUAD
# Lambrechts_2018_lung            Lung Squamous Cell Carcinoma             LUSC
# ...                                                      ...              ...
# Li_2023_head-and-neck  Hypopharygeal Squamous Cell Carcinoma             HSCC
# Oh_2023_pancreas            Pancreatic Ductal Adenocarcinoma             PDAC
# Yang_2023_colorectal                       Colorectal Cancer              CRC
# Song_2023_breast                               Breast Cancer             BRCA
# Xu_2022_breast                                 Breast Cancer             BRCA
#
#                        ...             instrument GEO accession  \
# Paulson_2018_skin      ...    Illumina HiSeq 2500     GSE117988
# Paulson_2018_skin      ...  Illumina NovaSeq 6000     GSE118056
# Laughney_2020_lung     ...    Illumina HiSeq 2500     GSE123904
# Lambrechts_2018_lung   ...              HiSeq4000           NaN
# Lambrechts_2018_lung   ...              HiSeq4000           NaN
# ...                    ...                    ...           ...
# Li_2023_head-and-neck  ...  Illumina NovaSeq 6000     GSE227156
# Oh_2023_pancreas       ...   Illumina NextSeq 500     GSE231535
# Yang_2023_colorectal   ...  Illumina NovaSeq 6000     GSE232525
# Song_2023_breast       ...            NextSeq 500     GSE234832
# Xu_2022_breast         ...  Illumina NovaSeq 6000     GSE188807
#
#                                                           other_metadata  \
# Paulson_2018_skin      The patient had a 22 month clinical response f...
# Paulson_2018_skin                                                    NaN
# Laughney_2020_lung                                              No smoke
# Lambrechts_2018_lung                          Tumor edge; Former smokers
# Lambrechts_2018_lung   Tumor core; Active smokers and some had mild c...
# ...                                                                  ...
# Li_2023_head-and-neck                                                NaN
# Oh_2023_pancreas       T3N1M0; Pathologic diagnosis: mod. Diff. PDAC;...
# Yang_2023_colorectal                                                 NaN
# Song_2023_breast       Invasive ductal carcinoma with micropapillary ...
# Xu_2022_breast                           T2NxM0; Molecular typing: Her-2
#
#                       Accession No. N_samples      protocol      Source  \
# Paulson_2018_skin         GSE117988         2  10X Genomics  CancerSCEM
# Paulson_2018_skin         GSE118056         2  10X Genomics  CancerSCEM
# Laughney_2020_lung        GSE123904        13  10X Genomics  CancerSCEM
# Lambrechts_2018_lung    E-MTAB-6149         6  10X Genomics  CancerSCEM
# Lambrechts_2018_lung    E-MTAB-6149         6  10X Genomics  CancerSCEM
# ...                             ...       ...           ...         ...
# Li_2023_head-and-neck     GSE227156        10      GEXSCOPE  CancerSCEM
# Oh_2023_pancreas          GSE231535         2  10X Genomics  CancerSCEM
# Yang_2023_colorectal      GSE232525         2  10X Genomics  CancerSCEM
# Song_2023_breast          GSE234832         3  10X Genomics  CancerSCEM
# Xu_2022_breast            GSE188807         2      GEXSCOPE  CancerSCEM
#
#                               Tissue Technology  \
# Paulson_2018_skin               skin        10x
# Paulson_2018_skin               skin        10x
# Laughney_2020_lung              lung        10x
# Lambrechts_2018_lung            lung        10x
# Lambrechts_2018_lung            lung        10x
# ...                              ...        ...
# Li_2023_head-and-neck  head-and-neck   GEXSCOPE
# Oh_2023_pancreas            pancreas        10x
# Yang_2023_colorectal      colorectal        10x
# Song_2023_breast              breast        10x
# Xu_2022_breast                breast   GEXSCOPE
#
#                                                      Disease
# Paulson_2018_skin                      Merkel cell carcinoma
# Paulson_2018_skin                      Merkel cell carcinoma
# Laughney_2020_lung                       Lung adenocarcinoma
# Lambrechts_2018_lung                     Lung adenocarcinoma
# Lambrechts_2018_lung            Lung Squamous Cell Carcinoma
# ...                                                      ...
# Li_2023_head-and-neck  Hypopharygeal Squamous Cell Carcinoma
# Oh_2023_pancreas                                        PDAC
# Yang_2023_colorectal                       Colorectal cancer
# Song_2023_breast                               Breast cancer
# Xu_2022_breast                                 Breast cancer
#
# [102 rows x 25 columns]
